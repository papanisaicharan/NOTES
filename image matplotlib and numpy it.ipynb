# %%
#https://matplotlib.org/users/image_tutorial.html  visit this link for more about plotting using matplot

# %% [markdown]
# trying the image tutorials

# %%
from matplotlib import pyplot as plt
import numpy as np
import cv2
img = cv2.imread('images/stinkbug.png')
print(np.array(img))
print(len(img[0]))
# for i in img[0]:
#     print(i[0])
# Out:
# [[[104 104 104]
#   [104 104 104]
#   [104 104 104]
#   ...
#   [109 109 109]
#   [109 109 109]
#   [109 109 109]]
#
#  [[105 105 105]
#   [105 105 105]
#   [105 105 105]
#   ...
#   [109 109 109]
#   [109 109 109]
#   [109 109 109]]
#
#  [[107 107 107]
#   [106 106 106]
#   [106 106 106]
#   ...
#   [110 110 110]
#   [110 110 110]
#   [110 110 110]]
#
#  ...
#
#  [[112 112 112]
#   [111 111 111]
#   [110 110 110]
#   ...
#   [116 116 116]
#   [115 115 115]
#   [115 115 115]]
#
#  [[113 113 113]
#   [113 113 113]
#   [112 112 112]
#   ...
#   [115 115 115]
#   [114 114 114]
#   [114 114 114]]
#
#  [[113 113 113]
#   [115 115 115]
#   [115 115 115]
#   ...
#   [114 114 114]
#   [114 114 114]
#   [113 113 113]]]
# 500

# %%
plt.imshow(img)

# %%
lum_img = img[:,:,0]
print(lum_img)
print(len(lum_img[0]))
lum_img[0]
# Out:
# [[104 104 104 ... 109 109 109]
#  [105 105 105 ... 109 109 109]
#  [107 106 106 ... 110 110 110]
#  ...
#  [112 111 110 ... 116 115 115]
#  [113 113 112 ... 115 114 114]
#  [113 115 115 ... 114 114 113]]
# 500
# array([104, 104, 104, 105, 105, 106, 106, 106, 108, 107, 106, 106, 107,
#        108, 108, 108, 110, 108, 109, 111, 112, 111, 111, 113, 112, 113,
#        113, 113, 113, 113, 114, 114, 114, 115, 115, 116, 116, 117, 117,
#        117, 118, 118, 118, 118, 118, 118, 119, 119, 120, 121, 121, 121,
#        121, 122, 123, 123, 124, 124, 123, 124, 124, 124, 124, 125, 125,
#        126, 125, 125, 125, 125, 125, 127, 126, 126, 126, 125, 125, 125,
#        126, 126, 124, 124, 125, 125, 126, 125, 125, 125, 125, 126, 126,
#        126, 126, 126, 127, 127, 127, 126, 126, 126, 126, 126, 127, 127,
#        127, 127, 127, 127, 127, 127, 127, 127, 128, 128, 128, 128, 128,
#        129, 129, 128, 129, 129, 129, 129, 129, 129, 129, 129, 130, 130,
# ...

# %%
kit = []
for i in range(100):
    kit.append(lum_img[i])
plt.imshow(kit)

# %%
plt.imshow(lum_img)

# %%
plt.imshow(lum_img, cmap="hot")

# %%
#you can also change colormaps on existing plot objects using the set_cmap() method:
imgplot = plt.imshow(lum_img)
imgplot.set_cmap('nipy_spectral')

# %%
#you can also change colormaps on existing plot objects using the set_cmap() method:
imgplot = plt.imshow(lum_img)
imgplot.set_cmap('flag')

# %% [markdown]
# in the IPython notebook with the inline backend, you can’t make changes to plots that have already been rendered. If you create imgplot here in one cell, you cannot call set_cmap() on it in a later cell and expect the earlier plot to change. Make sure that you enter these commands together in one cell. plt commands will not change plots from earlier cells.
#
# visit the link for cmap value:
#     https://matplotlib.org/examples/color/colormaps_reference.html

# %%
#It’s helpful to have an idea of what value a color represents.
imgplot = plt.imshow(lum_img)
plt.colorbar()

# %% [markdown]
# Examining a specific data range
#
# Sometimes you want to enhance the contrast in your image, or expand the contrast in a particular region while sacrificing the detail in colors that don’t vary much, or don’t matter.
# A good tool to find interesting regions is the histogram. To create a histogram of our image data, we use the hist() function.
#
# https://docs.scipy.org/doc/numpy-1.15.0/reference/generated/numpy.ravel.html
#
# x = np.array([[1, 2, 3], [3, 5, 6]])
# print(np.ravel(x))
# #output [1 2 3 3 4 5 6]

# %%
p = lum_img.ravel().tolist()
print(p)
p.sort()
set(p)
# Out:
# WARNING: some intermediate output was truncated.
# ...

# %%
len(lum_img)
# Out:
# 375

# %%
plt.hist(lum_img.ravel(),histtype='bar',bins=256)
plt.show()

# %%
imgplot = plt.imshow(lum_img, clim=(50,170))
